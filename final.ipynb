# %% [markdown]
# 1. There are only 26 Numerical Attributes in the dataset.
# 2. On the other hand we have 9 Categorical Attributes.

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.graph_objects as go
import plotly.express as px

# %%
import pandas as pd
data = pd.read_csv('employee_attrition_team04.csv')

# %%
data.head()
# Out:
#    Age Attrition BusinessTravel  DailyRate              Department  \
# 0   37        No  Travel_Rarely       1372  Research & Development
# 1   37        No  Travel_Rarely       1439  Research & Development
# 2   42        No  Travel_Rarely        635                   Sales
# 3   35        No  Travel_Rarely       1402                   Sales
# 4   24        No  Travel_Rarely       1371                   Sales
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          3  Life Sciences              1             391
# 1                 4          1  Life Sciences              1            1394
# 2                 1          1  Life Sciences              1             387
# 3                28          4  Life Sciences              1            1554
# 4                10          4      Marketing              1             507
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
data.tail()
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 1024   31       Yes  Travel_Frequently        667                   Sales
# 1025   45        No      Travel_Rarely        950  Research & Development
# 1026   38        No  Travel_Frequently        240  Research & Development
# 1027   48        No      Travel_Rarely        530                   Sales
# 1028   38       Yes      Travel_Rarely       1180  Research & Development
#
#       DistanceFromHome  Education    EducationField  EmployeeCount  \
# 1024                 1          4     Life Sciences              1
# 1025                28          3  Technical Degree              1
# 1026                 2          4     Life Sciences              1
# 1027                29          1           Medical              1
# 1028                29          1           Medical              1
#
#       EmployeeNumber  ...  RelationshipSatisfaction StandardHours  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1029 entries, 0 to 1028
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1029 non-null   int64
#  1   Attrition                 1029 non-null   object
#  2   BusinessTravel            1029 non-null   object
#  3   DailyRate                 1029 non-null   int64
#  4   Department                1029 non-null   object
#  5   DistanceFromHome          1029 non-null   int64
#  6   Education                 1029 non-null   int64
#  7   EducationField            1029 non-null   object
#  8   EmployeeCount             1029 non-null   int64
#  9   EmployeeNumber            1029 non-null   int64
#  10  EnvironmentSatisfaction   1029 non-null   int64
#  11  Gender                    1029 non-null   object
#  12  HourlyRate                1029 non-null   int64
#  13  JobInvolvement            1029 non-null   int64
# ...

# %%
data.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1029.000000  1029.000000       1029.000000  1029.000000         1029.0
# mean     36.974733   803.956268          9.243926     2.861030            1.0
# std       9.295168   400.826235          8.165588     1.039646            0.0
# min      18.000000   103.000000          1.000000     1.000000            1.0
# 25%      30.000000   468.000000          2.000000     2.000000            1.0
# 50%      36.000000   810.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1029.000000              1029.000000  1029.000000     1029.000000
# mean      1014.106900                 2.762877    66.546161        2.726919
# ...

# %%
data.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeCount               0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# Over18                      0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StandardHours               0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# ...

# %%
import missingno as msno
msno.bar(data)
# Out:
# <Axes: >

# %%
data.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# Over18                      object
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# ...

# %%
data.nunique()
# Out:
# Age                           43
# Attrition                      2
# BusinessTravel                 3
# DailyRate                    703
# Department                     3
# DistanceFromHome              29
# Education                      5
# EducationField                 6
# EmployeeCount                  1
# EmployeeNumber              1029
# EnvironmentSatisfaction        4
# Gender                         2
# HourlyRate                    71
# JobInvolvement                 4
# JobLevel                       5
# JobRole                        9
# JobSatisfaction                4
# MaritalStatus                  3
# MonthlyIncome                961
# MonthlyRate                 1006
# NumCompaniesWorked            10
# Over18                         1
# OverTime                       2
# PercentSalaryHike             15
# PerformanceRating              2
# RelationshipSatisfaction       4
# StandardHours                  1
# StockOptionLevel               4
# ...

# %%
data.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeCount',
#        'EmployeeNumber', 'EnvironmentSatisfaction', 'Gender', 'HourlyRate',
#        'JobInvolvement', 'JobLevel', 'JobRole', 'JobSatisfaction',
#        'MaritalStatus', 'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked',
#        'Over18', 'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StandardHours', 'StockOptionLevel',
#        'TotalWorkingYears', 'TrainingTimesLastYear', 'WorkLifeBalance',
#        'YearsAtCompany', 'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# # EDA

# %%
data['Attrition'].value_counts()
# Out:
# No     868
# Yes    161
# Name: Attrition, dtype: int64

# %%
# let's encode the attrition column so we can use it for EDA
data['Attrition'] = data['Attrition'].factorize(['No','Yes'])[0]
data.head()
# Out:
#    Age  Attrition BusinessTravel  DailyRate              Department  \
# 0   37          0  Travel_Rarely       1372  Research & Development
# 1   37          0  Travel_Rarely       1439  Research & Development
# 2   42          0  Travel_Rarely        635                   Sales
# 3   35          0  Travel_Rarely       1402                   Sales
# 4   24          0  Travel_Rarely       1371                   Sales
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          3  Life Sciences              1             391
# 1                 4          1  Life Sciences              1            1394
# 2                 1          1  Life Sciences              1             387
# 3                28          4  Life Sciences              1            1554
# 4                10          4      Marketing              1             507
#
#    ...  StandardHours StockOptionLevel  TotalWorkingYears  \
# ...

# %%
plt.figure(figsize=(8,8))
pie = data.groupby('Attrition')['Attrition'].count()
plt.pie(pie, explode=[0.1, 0.1], labels=['No', 'Yes'], autopct='%1.1f%%');

# %% [markdown]
# The employee attrition rate of this organization is 15.6% while 84% of the employees in the dataset have not left the company.

# %% [markdown]
# # Business Travel

# %%
data['BusinessTravel'].value_counts()
# Out:
# Travel_Rarely        726
# Travel_Frequently    195
# Non-Travel           108
# Name: BusinessTravel, dtype: int64

# %%
# #Visualization to show Total Employees by Businees Travel.
# plt.figure(figsize=(14,6))
# plt.subplot(1,2,1)
# value_1 = data["BusinessTravel"].value_counts()
# plt.title("Employees by Business Travel", fontweight="black", size=20, pad=20)
# plt.pie(value_1.values, labels=value_1.index, autopct="%.1f%%",pctdistance=0.75,startangle=90,
#         colors=['#E84040', '#E96060', '#E88181'],textprops={"fontweight":"black","size":15})
# center_circle = plt.Circle((0, 0), 0.4, fc='white')
# fig = plt.gcf()
# fig.gca().add_artist(center_circle)

# #Visualization to show Attrition Rate by Businees Travel.
# plt.subplot(1,2,2)
# new_df = data[data["Attrition"]=="Yes"]
# value_2 = new_df["BusinessTravel"].value_counts()
# attrition_rate = np.floor((value_2/value_1)*100).values
# sns.barplot(x=value_2.index,y=value_2.values,palette=["#11264e","#6faea4","#FEE08B"])
# plt.title("Attrition Rate by Businees Travel",fontweight="black",size=20,pad=20)
# for index,value in enumerate(value_2):
#     plt.text(index,value,str(value)+" ("+str(int(attrition_rate[index]))+"% )",ha="center",va="bottom",
#              size=15,fontweight="black")
# plt.tight_layout()
# plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='BusinessTravel', hue='Attrition', data=data, palette='seismic')
plt.title("Attrition with BusinessTravel")
plt.show()

# %% [markdown]
# Most employees who travel rarely don't leave the company. From the plot we can tell, sending employees on business travels or not doesn't really make much of a difference and doesn't have a significant effect on attrition.

# %% [markdown]
# Inference:
# 1. Most of the employees in the organization Travel Rarely.
# 2. Highest employee attrition can be observed by those employees who Travels Frequently.
# 3. Lowest employee attrition can be observed by those employees who are Non-Travel.
#
# Solution:
# 1. The organization can split travelling among the employees to reduce the burden of employees who travel frequently.
# 2. This will definitely help in reduicing the attrition rate eith respect to business travel.

# %%
data['Department'].value_counts()
# Out:
# Research & Development    672
# Sales                     309
# Human Resources            48
# Name: Department, dtype: int64

# %%
# Filter the DataFrame for employees with attrition
attrition_data = data[data['Attrition'] == 'Yes']

# Calculate the count of attritions per department
attrition_by_department = attrition_data['Department'].value_counts()

# Display the department with the most attritions
most_attritions_department = attrition_by_department.idxmax()
attritions_count = attrition_by_department.max()

print(f"The department with the most attritions is '{most_attritions_department}' with {attritions_count} attritions.")
# Out:
# The department with the most attritions is 'Research & Development' with 89 attritions.

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='Department', hue='Attrition', data=data, palette='seismic')
plt.title("Attrition with Department")
plt.show()

# %% [markdown]
# Research and development department has a higher rate of attrition with 89 attritions.

# %%
data['EducationField'].value_counts()
# Out:
# Life Sciences       427
# Medical             319
# Marketing           105
# Technical Degree    101
# Other                57
# Human Resources      20
# Name: EducationField, dtype: int64

# %%
da4=data.groupby(['EducationField'])[['Attrition']].value_counts().reset_index()
da4.set_axis(['EducationField','Attrition','Count'],axis='columns')
da4
# Out:
#       EducationField Attrition    0
# 0    Human Resources        No   15
# 1    Human Resources       Yes    5
# 2      Life Sciences        No  365
# 3      Life Sciences       Yes   62
# 4          Marketing        No   82
# 5          Marketing       Yes   23
# 6            Medical        No  279
# 7            Medical       Yes   40
# 8              Other        No   50
# 9              Other       Yes    7
# 10  Technical Degree        No   77
# 11  Technical Degree       Yes   24

# %%
plt.figure(figsize = (8,5))
explode = (0.1,0,0,0,0,0)
label=['Life Sciences',"Medical","Marketing","Technical Degree","Other","Human Resources"]
plt.pie(data['EducationField'].value_counts(), explode = explode, labels = label,autopct = '%1.1f%%',wedgeprops = {"edgecolor" : "w",'linewidth' : 2})
plt.axis('equal') 
plt.show()

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='EducationField', hue='Attrition', data=data, palette='seismic')
plt.title("Attrition with EducationField")
plt.show()

# %% [markdown]
# Life and sciences has more rate of attrition.
#
# Field of Life Science is bigest field ,where employees work in it and has heigher number from left employees.

# %%
data['Gender'].value_counts()
# Out:
# Male      617
# Female    412
# Name: Gender, dtype: int64

# %%
G_A=data.groupby(['Gender'])[['Attrition']].value_counts().reset_index()
G_A
# Out:
#    Gender Attrition    0
# 0  Female        No  351
# 1  Female       Yes   61
# 2    Male        No  517
# 3    Male       Yes  100

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='Gender', hue='Attrition', data=data, palette='seismic')
plt.title("Attrition with Gender")
plt.show()

# %% [markdown]
# The number of male employees in the organization accounts for a higher proportion than female employees by more than 20%.
# Male employees are leaving more from the organization compared to female employees. The number of male still greater than num of female in both (yes or no attrition)

# %%
data['JobRole'].value_counts()
# Out:
# Sales Executive              216
# Research Scientist           207
# Laboratory Technician        173
# Manufacturing Director       109
# Healthcare Representative     93
# Manager                       68
# Sales Representative          66
# Research Director             56
# Human Resources               41
# Name: JobRole, dtype: int64

# %%
# Calculate the count of attritions per job role
attrition_by_job_role = attrition_data['JobRole'].value_counts()

# Display the job role with the most attritions
most_attritions_job_role = attrition_by_job_role.idxmax()
attritions_count = attrition_by_job_role.max()

print(f"The job role with the most attritions is '{most_attritions_job_role}' with {attritions_count} attritions.")
# Out:
# The job role with the most attritions is 'Laboratory Technician' with 40 attritions.

# %%
fig = px.histogram(attrition_data, x = attrition_data['JobRole'])
fig.show()

# %%
data['OverTime'].value_counts()
# Out:
# No     735
# Yes    294
# Name: OverTime, dtype: int64

# %%
overtime_counts = data.groupby('OverTime')['Attrition'].value_counts().to_frame()
sizes = overtime_counts.values
labels = overtime_counts.index
labels = [labels[2][1], labels[3][1]]
overtime_counts
# Out:
#                     Attrition
# OverTime Attrition
# No       No               665
#          Yes               70
# Yes      No               203
#          Yes               91

# %%
import plotly.graph_objects as go
labels = ['Overtime', 'No Overtime']
values = [289, 127]

fig = go.Figure()
fig.add_trace(go.Pie(labels=labels, values=values, hole=0.5))
fig.update_layout(title='Overtime X Attrition', autosize=False, width=500, height=450)
fig.show()

# %%
sns.countplot(data=data, x='OverTime', hue='Attrition', palette='muted')
plt.title('Attrition Count by Overtime')
plt.xlabel('Overtime')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# People with overtime have a higher rate of attrition

# %%
data['DistanceFromHome'].value_counts()
# Out:
# 1     154
# 2     140
# 7      66
# 8      60
# 9      56
# 10     54
# 3      51
# 5      47
# 4      45
# 6      43
# 16     23
# 23     21
# 11     21
# 18     20
# 29     20
# 24     20
# 26     19
# 20     18
# 15     17
# 19     16
# 25     16
# 28     16
# 17     14
# 12     14
# 14     13
# 21     12
# 13     12
# 22     12
# 27      9
# Name: DistanceFromHome, dtype: int64

# %%
plt.figure(figsize=(8, 6))
sns.boxplot(data=data, x='Attrition', y='DistanceFromHome', palette='muted')
plt.title('Effect of Distance from Home on Attrition')
plt.xlabel('Attrition')
plt.ylabel('Distance from Home')
plt.show()

# %% [markdown]
# The further the distance the higher the rate of attrition

# %% [markdown]
# # Age

# %%
data[['Age']].value_counts().sort_values(ascending=False).head(10)
# Out:
# Age
# 35     57
# 36     52
# 34     46
# 29     44
# 32     43
# 31     42
# 38     40
# 30     39
# 33     38
# 28     36
# dtype: int64

# %%
data[['Age']].value_counts().sort_values(ascending=False).tail()
# Out:
# Age
# 18     6
# 19     6
# 59     5
# 60     4
# 57     1
# dtype: int64

# %% [markdown]
# Most employees are in their 30s with 35 year olds having the highest count and lowest are people at around the age 60 or less than 20.

# %%
#Visualization to show Employee Distribution by Age.
plt.figure(figsize=(13.5,6))
plt.subplot(1,2,1)
sns.histplot(x="Age",hue="Attrition",data=data,kde=True,palette=["#11264e","#6faea4"])
plt.title("Employee Distribution by Age",fontweight="black",size=20,pad=10)


#Visualization to show Employee Distribution by Age & Attrition.
plt.subplot(1,2,2)
sns.boxplot(x="Attrition",y="Age",data=data,palette=["#D4A1E7","#6faea4"])
plt.title("Employee Distribution by Age & Attrition",fontweight="black",size=20,pad=10)
plt.tight_layout()
plt.show()

# %% [markdown]
# 1.Most of the emloyees are between age 30 to 40.
#
# 2.We can clearly observe a trend that as the age is increasing the attrition is decreasing.
#
# 3.From the boxplot we can also observe that the medain age of employee who left the organization is less than the employees
#
# who are working in the organization.
#
# 4.Employees with young age leaves the company more compared to elder employees.

# %%
plt.figure(figsize=(13,4))
sns.lineplot(data=data,x='Age',y='MonthlyIncome',hue="Attrition", palette='muted')
# Out:
# <Axes: xlabel='Age', ylabel='MonthlyIncome'>

# %%
maxx=data['Age'].max()
minn=data['Age'].min()
print(maxx)
print(minn)
# Out:
# 60
# 18

# %%
interval = pd.interval_range(start= 18 , freq = 10 , end = 68)
data['Age_Interval'] = pd.cut(data['Age'] , bins = interval , labels= [])
da=data.groupby(['Attrition'])[['Age_Interval']].value_counts().reset_index()
da.set_axis(['Attrition','Age_interval','Count'],axis='columns')
da
# Out:
#   Attrition Age_Interval    0
# 0        No     (28, 38]  370
# 1        No     (38, 48]  236
# 2        No     (18, 28]  135
# 3        No     (48, 58]  115
# 4        No     (58, 68]    9
# 5       Yes     (28, 38]   66
# 6       Yes     (18, 28]   51
# 7       Yes     (38, 48]   23
# 8       Yes     (48, 58]   18
# 9       Yes     (58, 68]    0

# %%
plt.figure(figsize=(5,4))
sns.barplot(data=da,x='Age_Interval',y='count',hue="Attrition", palette='muted')
plt.title("Ratio of Age and Attrition")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[112], line 2
#       1 plt.figure(figsize=(5,4))
# ----> 2 sns.barplot(data=da,x='Age_Interval',y='count',hue="Attrition", palette='muted')
#       3 plt.title("Ratio of Age and Attrition")
#
# File c:\Users\Faith\anaconda3\Lib\site-packages\seaborn\categorical.py:2755, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, units, seed, orient, color, palette, saturation, width, errcolor, errwidth, capsize, dodge, ci, ax, **kwargs)
#    2752 if estimator is len:
#    2753     estimator = "size"
# -> 2755 plotter = _BarPlotter(x, y, hue, data, order, hue_order,
#    2756                       estimator, errorbar, n_boot, units, seed,
#    2757                       orient, color, palette, saturation,
#    2758                       width, errcolor, errwidth, capsize, dodge)
#    2760 if ax is None:
# ...

# %%
sns.kdeplot(data=data,x="MonthlyIncome",shade=True)
# Out:
# C:\Users\Faith\AppData\Local\Temp\ipykernel_20860\4259610077.py:1: FutureWarning:
#
#
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
# <Axes: xlabel='MonthlyIncome', ylabel='Density'>

# %%
plt.figure(figsize = (10,5))
sns.scatterplot(data=data,x='MonthlyIncome',y='HourlyRate',hue="Attrition",style="Department",size="Department",sizes=(20,50), palette='muted')
plt.ylabel('Attrition')
plt.xlabel('MonthlyIncome')
plt.title("Ratio between Income and HourlyRate")
# Out:
# Text(0.5, 1.0, 'Ratio between Income and HourlyRate')

# %% [markdown]
# most employees have Monthly rate 1000 to 7500 left jobs anf alot of them at sales and research & devlopment department so may
#
# be income effect on attrition.

# %%
data.groupby('WorkLifeBalance')['Attrition'].value_counts().to_frame()
# Out:
#                            Attrition
# WorkLifeBalance Attrition
# 1               No                37
#                 Yes               14
# 2               No               192
#                 Yes               40
# 3               No               555
#                 Yes               90
# 4               No                84
#                 Yes               17

# %% [markdown]
# This implies that a better work-life balance might contribute to employee retention

# %%
plt.figure(figsize=(15,7))
sns.kdeplot(data=data, x = "YearsWithCurrManager", hue="Attrition", palette='muted')
# Out:
# <Axes: xlabel='YearsWithCurrManager', ylabel='Density'>

# %%
factors = ['WorkLifeBalance', 'JobSatisfaction', 'EnvironmentSatisfaction']

for factor in factors:
    plt.figure(figsize=(9, 6))
    for attrition_category in data['Attrition'].unique():
        data_attrition = data[data['Attrition'] == attrition_category]
        plt.plot(
            data_attrition.groupby(factor).size().index,
            data_attrition.groupby(factor).size().values,
            marker='o',
            label=f'Attrition: {attrition_category}'
        )
    
    plt.title(f'{factor} vs Attrition')
    plt.xlabel(factor)
    plt.ylabel('Count')
    plt.legend()
    plt.show()

# %%
attrition_rates = attrition_data.groupby('TotalWorkingYears')['Attrition'].value_counts().unstack()
attrition_data
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 9      25       Yes      Travel_Rarely        383                   Sales
# 19     40       Yes      Travel_Rarely        299                   Sales
# 22     32       Yes      Travel_Rarely       1045                   Sales
# 23     31       Yes  Travel_Frequently        703                   Sales
# 26     40       Yes      Travel_Rarely       1329  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1005   39       Yes  Travel_Frequently        203  Research & Development
# 1009   34       Yes  Travel_Frequently        988         Human Resources
# 1010   33       Yes      Travel_Rarely        603                   Sales
# 1024   31       Yes  Travel_Frequently        667                   Sales
# 1028   38       Yes      Travel_Rarely       1180  Research & Development
#
#       DistanceFromHome  Education   EducationField  EmployeeCount  \
# ...

# %%
plt.figure(figsize=(10, 6))
sns.lineplot(data=attrition_rates.reset_index(), x='TotalWorkingYears', y='Yes', marker='o', label='Attrition Rate')
plt.title('Attrition Rate by Work Experience')
plt.xlabel('Years of Work Experience')
plt.ylabel('Attrition Rate')
plt.legend()
plt.grid(True)
plt.show()

# %%
# Calculate attrition rates for each education level
attrition_rates_education = data.groupby('Education')['Attrition'].value_counts().unstack().fillna(0)
attrition_rates_education
# Out:
# Attrition   No  Yes
# Education
# 1          103   26
# 2          184   34
# 3          322   59
# 4          232   37
# 5           27    5

# %%
fig, ax = plt.subplots(figsize=(12, 6))
bar_width = 0.35
index = range(5)

# Plotting 'Yes' counts
bar1 = plt.bar(index, attrition_rates_education['Yes'], bar_width, label='Yes', color='skyblue')
# Plotting 'No' counts
bar2 = plt.bar([i + bar_width for i in index], attrition_rates_education['No'], bar_width, label='No', color='salmon')

plt.xlabel('Education Level')
plt.ylabel('Count')
plt.title('Attrition Rates by Education Level')
plt.xticks([i + bar_width / 2 for i in index], attrition_rates_education.index)
plt.legend()
plt.tight_layout()
plt.show()

# %%
sns.boxplot(data["YearsAtCompany"])
# Out:
# <Axes: >

# %% [markdown]
# Most employees remain in the company for 3-9 years with median being 5 years.

# %%
# We can use a heatmap to check correlation between the variables.
data = data.drop(['EmployeeCount','StandardHours'], axis=1) # dropping these two columns because they only have one value

# %%
plt.figure(figsize=(20, 20))
sns.heatmap(data.corr(), cmap='Reds', annot=True, fmt='.2f');
# Out:
# C:\Users\Faith\AppData\Local\Temp\ipykernel_20860\3484769990.py:2: FutureWarning:
#
# The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.

# %% [markdown]
# there isn't a very strong correlation of the target column with any of the numerical columns. But we can see other correlations such as;
#
#     More senior employees have higher total working years (very obvious)
#     Higher performance ratings lead to salary hike percentage to increase
#     The more years an employee puts in, the more their monthly income increases
#     A lot of employees remain in their current role and also under the same manager as years pass by meaning they don't get promotion and this could be a major factor contributing to attrition
#
#     From here, we can deduct that the lack of promotions may be a crucial factor to attritions.

# %% [markdown]
# percentsalaryhike has heigher corrleation with performancerating
#
# job level with monthly income and totalworkingyears
#
# monthlyincome with totalworkingyears

# %% [markdown]
# # EDA
